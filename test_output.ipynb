# %%
import pandas as pd
pd.set_option('display.max_colwidth', 500)
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)

# %%
df = pd.read_csv('output.csv')
df.head()
# Out:
#                                    mrid  cause  communitydescriptor  \
# 0                                   NaN    NaN                42003
# 1  be691428-8fb6-4fec-8115-f5d99568c6fe    NaN                37017
#
#    customersrestored  metersaffected          reportedstarttime  statuskind  \
# 0                NaN               1  2025-03-14T19:40:00+00:00         NaN
# 1                NaN               1                        NaN         NaN
#
#    utilitydisclaimer  \
# 0                NaN
# 1                NaN
#
#                                                                                    incident  \
# 0  {"Location": {"kind": "electricalNetwork", "CoordinateSystem": {"crsUrn": "EPSG:4326"}}}
# 1  {"Location": {"kind": "electricalNetwork", "CoordinateSystem": {"crsUrn": "EPSG:4326"}}}
#
#                                                                      outagearea  \
# 0  {"earliestReportedTime": "2025-03-14T19:40:00Z", "outageAreaKind": "county"}
# 1                                                  {"outageAreaKind": "county"}
#
#                                                                                                                                                                       names  \
# 0             [{"name": "DUQUESNE LIGHT CO", "nameType": "UtilityName", "nameTypeAuthority": "EIA"}, {"name": "5487", "nameType": "UtilityId", "nameTypeAuthority": "EIA"}]
# 1  [{"name": "FOUR COUNTY ELEC MEMBER CORP", "nameType": "UtilityName", "nameTypeAuthority": "EIA"}, {"name": "6640", "nameType": "UtilityId", "nameTypeAuthority": "EIA"}]
#
#    estimatedrestorationtime  causekind  incident_cause  \
# 0                       NaN        NaN             NaN
# 1                       NaN        NaN             NaN
#
#                                                             incident_location  \
# 0  {"kind": "electricalNetwork", "CoordinateSystem": {"crsUrn": "EPSG:4326"}}
# 1  {"kind": "electricalNetwork", "CoordinateSystem": {"crsUrn": "EPSG:4326"}}
#
#   incident_location_kind outagearea_outageareakind  \
# 0      electricalNetwork                    county
# 1      electricalNetwork                    county
#
#                                 name           state geom_type  \
# 0             DUQUESNE LIGHT CO,5487    Pennsylvania   Feature
# 1  FOUR COUNTY ELEC MEMBER CORP,6640  North Carolina   Feature
#
#                                                                                                                                                                                                                                                                                                   geom_geometry_coordinates  \
# 0                                                                                       [[[[-79.871425, 40.197390999], [-79.871696, 40.197300999], [-79.87251, 40.197264999], [-79.874857, 40.197220999], [-79.877877, 40.197033999], [-79.881115, 40.196646999], [-79.885599, 40.195376999], [-79.871425, 40.197390999]]]]
# 1  [[[[-78.494705, 34.856181999], [-78.495151, 34.855680999], [-78.495243, 34.855188999], [-78.495445, 34.854978999], [-78.496074, 34.855048999], [-78.514572, 34.847037999], [-78.513009, 34.848170999], [-78.512017, 34.848922999], [-78.507848, 34.851484999], [-78.506288, 34.852572999], [-78.494705, 34.856181999]]]]
#
#   geom_geometry_type  centroid_lon  centroid_lat
# 0       MultiPolygon    -79.981217     40.468789
# 1       MultiPolygon    -78.563700     34.614633
